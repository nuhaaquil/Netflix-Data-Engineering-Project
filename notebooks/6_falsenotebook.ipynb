# %% [markdown]
# This notebook runs if weekday number is not equal to 7

# %%
# This is used to get the value of any nb that is returning the data as output.
# this means, value of job used in nb connected to it

# taskKey: task name
var = dbutils.jobs.taskValues.get(taskKey="WeekdayLookup",key="weekoutput",debugValue="1")

# %%
print(var)
# Out:
# 1
